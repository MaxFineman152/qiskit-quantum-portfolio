# %%
from qiskit import *
from qiskit_aer import Aer
from qiskit_ibm_runtime import QiskitRuntimeService

# %%
QiskitRuntimeService.save_account(
    token=open("ibmapi.txt", "r").read().strip(),
    set_as_default=True
)
# Out:
# ---------------------------------------------------------------------------
# AccountAlreadyExistsError                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 QiskitRuntimeService.save_account(
#       2     token=open("ibmapi.txt", "r").read().strip(),
#       3     set_as_default=True
#       4 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit_ibm_runtime\qiskit_runtime_service.py:888, in QiskitRuntimeService.save_account(token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#     835 @staticmethod
#     836 def save_account(
#     837     token: str | None = None,
#    (...)    850     tags: list[str] | None = None,
#     851 ) -> None:
#     852     """Save the account to disk for future use.
#     853
#     854     Args:
#    (...)    886
#     887     """
# --> 888     AccountManager.save(
#     889         token=token,
#     890         url=url,
#     891         instance=instance,
#     892         channel=channel,
#     893         filename=filename,
#     894         name=name,
#     895         proxies=ProxyConfiguration(**proxies) if proxies else None,
#     896         verify=verify,
#     897         overwrite=overwrite,
#     898         set_as_default=set_as_default,
#     899         private_endpoint=private_endpoint,
#     900         region=region,
#     901         plans_preference=plans_preference,
#     902         tags=tags,
#     903     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit_ibm_runtime\accounts\management.py:83, in AccountManager.save(cls, token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#      69 filename = os.path.expanduser(filename)
#      71 config = Account.create_account(
#      72     channel=channel,  # type: ignore[arg-type]
#      73     token=token,  # type: ignore[arg-type]
#    (...)     81     tags=tags,
#      82 )
# ---> 83 return save_config(
#      84     filename=filename,
#      85     name=name,
#      86     overwrite=overwrite,
#      87     config=config
#      88     # avoid storing invalid accounts
#      89     .validate().to_saved_format(),
#      90     set_as_default=set_as_default,
#      91 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\qiskit_ibm_runtime\accounts\storage.py:35, in save_config(filename, name, config, overwrite, set_as_default)
#      32     data = json.load(json_in)
#      34 if data.get(name) and not overwrite:
# ---> 35     raise AccountAlreadyExistsError(
#      36         f"Named account ({name}) already exists. Set overwrite=True to overwrite."
#      37     )
#      39 data[name] = config
#      41 # if set_as_default, but another account is defined as default, user must specify overwrite to
#      42 # change the default account.
#
# AccountAlreadyExistsError: 'Named account (default-ibm-quantum-platform) already exists. Set overwrite=True to overwrite.'

# %%
service = QiskitRuntimeService()
# Out:
# qiskit_runtime_service.__init__:WARNING:2026-09-16 15:23:16,733: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService(). Alternatively, pass instance='auto' or save it to your account for auto-selection without warning.

# %%
for backend in service.backends():
    try:
        qubit_count = backend.num_qubits
    except:
        qubit_count = "unknown"
    
    print(f"{backend.name} : {backend.status().pending_jobs} & {qubit_count} qubits")
# Out:
# qiskit_runtime_service.backends:WARNING:2026-09-16 15:23:18,651: Loading instance: open-instance, plan: open
# ibm_fez : 243 & 156 qubits
# ibm_marrakesh : 8 & 156 qubits
# ibm_kingston : 101 & 156 qubits

# %%
Aer.backends()
# Out:
# [AerSimulator('aer_simulator'),
#  AerSimulator('aer_simulator_statevector'),
#  AerSimulator('aer_simulator_density_matrix'),
#  AerSimulator('aer_simulator_stabilizer'),
#  AerSimulator('aer_simulator_matrix_product_state'),
#  AerSimulator('aer_simulator_extended_stabilizer'),
#  AerSimulator('aer_simulator_unitary'),
#  AerSimulator('aer_simulator_superop'),
#  QasmSimulator('qasm_simulator'),
#  StatevectorSimulator('statevector_simulator'),
#  UnitarySimulator('unitary_simulator')]

# %%
service.backends()
# Out:
# qiskit_runtime_service.backends:WARNING:2026-09-16 15:24:09,651: Loading instance: open-instance, plan: open
# [<IBMBackend('ibm_fez')>,
#  <IBMBackend('ibm_marrakesh')>,
#  <IBMBackend('ibm_kingston')>]
